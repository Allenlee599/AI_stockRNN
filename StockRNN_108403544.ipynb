# %% [markdown]
# <a href="https://colab.research.google.com/github/Allenlee599/AI_stockRNN/blob/main/StockRNN_108403544.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://i.imgur.com/3twMqGw.png)
#
# # 作業2 : 股票預測
#
# ## **請挑選一家公司來做預測**
#
# 資料集: [鉅亨網](https://www.cnyes.com/)
#
# > **資料集說明**
#
# 別人恐懼我貪婪，一張不賣奇蹟來。
#
# >**作業說明**
#
# **第一步驟**: 左上角 檔案->在雲端硬碟建立副本。
#
# **第二步驟**: 右上角 共用->取得連結->任何知道這個連結的人都能編輯
#
# **第三步驟**: 左上角 執行階段->更變執行類型->GPU。 可以加快模型速度
#
# **第四步驟**: 檔案名稱，請填寫你的學號，把副本上下引號刪掉
#
# 請 **隨意修改** 這個colab的程式來完成訓練RNN模型。**不必一定要照著todo提示走。**
# 繳交時記得改檔案標題的學號。
#
# 這次作業的重點在於RNN的維度問題。
#
# > **作業限制**
#
# 1. 不要動資料集、不要在訓練時偷看test data
# 2. 模型請手刻、手疊，**不要用Transfer Learning**，你可以手刻transformer。
# 3. **不要抄襲**
#
# > **作業繳交**
#
# 1. 完成訓練後保存output結果，更改**檔名學號**，左上角 檔案->下載 成ipynb檔。
# 2. 交一個**pdf**檔，裡面需要附上**你的作業colab連結(設為可編輯、所有人觀看)**、姓名學號年級、過程和執行結果的截圖，並說明你程式撰寫的過程、本次作業心得(字數不限)。
# 3. 上述三個檔案繳交至ee-class。(Text Generation、Stock、PDF)
#
# > **繳交期限**
#
# 1. 電子商務技術(IM5002): 期限至2021/5/16(一) 23:59分
# 2. 人工智慧與機器學習(IM3078): 期限至2022/5/16(一) 23:59分
# 3. 電子商務智慧技術(IMA0200): 期限至2022/5/14(六) 23:59分
#
# > **算分標準**
#
# Text Generation(20) + Stock RNN(30) + Predict function(20分) + 30分文件
# 1.  [Text Generation](https://colab.research.google.com/drive/1bMkAUaiivMaOr8Sd1Ui-KJeoFImEVUqA?usp=sharing) 換個其他資料集來訓練，完成就20分
# 2. Stock RNN完成模型就30分
# 3. predit function有寫出來就20分(第七段)
# 4. 30分是文件分數
# 5. 記得把以上評分標準截圖、並與你的心得一起貼上pdf
#
# 有問題再來信助教: chiachentu@g.ncu.edu.tw(凃家甄)、lufor129@g.ncu.edu.tw(黃智輝)

# %%
# 太多人同時存取可能會報cannot retrieve file error
# 點擊you may still be able to access 下面那個連結再自行上傳檔案即可

import os

if(os.path.isfile("./train.csv") == False or os.path.isfile("./test.csv") == False):
  # !wget -O train.csv "http://140.115.82.54/NN/Recurrent/train.csv"
  # !wget -O test.csv "http://140.115.82.54/NN/Recurrent/test.csv"
  # !gdown --id 1iK40K9oXsmhJGs7XSn7q3I1XuPtsZiSj --output "./train.csv"
  # !gdown --id 1kZIgeeTnzQf6GJGJuqOe9BgkFa8qb7hJ --output "./test.csv"
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1iK40K9oXsmhJGs7XSn7q3I1XuPtsZiSj
# To: /content/train.csv
# 100% 138k/138k [00:00<00:00, 78.3MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1kZIgeeTnzQf6GJGJuqOe9BgkFa8qb7hJ
# To: /content/test.csv
# 100% 2.36k/2.36k [00:00<00:00, 4.16MB/s]

# %% [markdown]
# ## 1. 讀入Package

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import random
import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %% [markdown]
# ## 2. 取得資料集

# %%
train_df = pd.read_csv("./train.csv")
train_df = train_df[::-1]
print("company : ",train_df["company"].unique())
train_df.head()
# Out:
# company :  [2317 2454 2330]
#       company      date  price
# 6687     2317  2012/1/2   81.4
# 6686     2317  2012/1/3   82.7
# 6685     2317  2012/1/4   83.2
# 6684     2317  2012/1/5   83.2
# 6683     2317  2012/1/6   83.9

# %%
test_df = pd.read_csv("./test.csv")
test_df = test_df[::-1]
print("test data shape : ",test_df.shape)
test_df.head()
# Out:
# test data shape :  (117, 3)
#      company      date  price
# 116     2317  2021/2/1  113.0
# 115     2317  2021/2/2  116.5
# 114     2317  2021/2/3  116.5
# 113     2317  2021/2/4  114.0
# 112     2317  2021/2/5  113.5

# %%
####################################
#                 #
# 自己決定三家公司哪家公司(填數字)#
# 挑選一家公司來做訓練、預測   #
#                 #
#                 #
####################################
companys = {"2330":"TSMC","2454":"MEDIATEK","2317":"FOXCONN"}
company_id = 2330

# %%
company = train_df[train_df["company"] == company_id]
company.index = company["date"]
company.head()
# Out:
#           company      date  price
# date
# 2012/1/2     2330  2012/1/2   75.0
# 2012/1/3     2330  2012/1/3   75.7
# 2012/1/4     2330  2012/1/4   75.8
# 2012/1/5     2330  2012/1/5   76.0
# 2012/1/6     2330  2012/1/6   75.6

# %%
def include_last_iter(start,end,step):
  i = start
  while i < end:
      yield i
      i += step
  yield end-1

# %%
plt.figure(figsize=(16, 8))
plt.subplots_adjust(hspace=0.5)
for index,c in enumerate(companys):
  plt.subplot(2,2,index+1)
  company_df = train_df[train_df["company"] == int(c)]
  plt.plot(company_df["date"],company_df["price"])
  plt.xticks(list(include_last_iter(0,company_df.shape[0],250)),rotation=30)
  plt.title(companys[c])
  plt.xlabel("Date")
  plt.ylabel("price")
    
plt.show()

# %% [markdown]
# ## 3. 資料前處理

# %%
# 切分training data & validation data
total_len = company.shape[0]
training_len = 2100
validation_data = total_len - training_len

print("總共有 : ",total_len,"筆")
print("訓練用 : (前)",training_len,"筆")
print("驗證用 : (後)",validation_data,"筆")
# Out:
# 總共有 :  2232 筆
# 訓練用 : (前) 2100 筆
# 驗證用 : (後) 132 筆

# %%
# 自己做 MinMax Transformer 前處理 
class MinMaxTransformer:
  def __init__(self):
    self.min = None
    self.max = None
    self.distance = None

  def fit(self,data):
    self.min = min(data)
    self.max = max(data)
    self.distance = self.max - self.min
    out = [(d-self.min)/self.distance for d in data]
    return out

  def recover(self,data):
    out = [d*self.distance+self.min for d in data]
    return out

  def transform(self,data):
    out = [(d-self.min)/self.distance for d in data]
    return out

  def transform_one(self,data):
    return (data-self.min)/self.distance

# %%
train_prices = company["price"].values

scalar = MinMaxTransformer()
scalar_data = scalar.fit(train_prices)

# %%
# 做正規化
print("origin data : ",train_prices[:5])
print("transform data : ",scalar_data[:5])
print("recover data : ",scalar.recover(scalar_data[:5]))
# Out:
# origin data :  [75.  75.7 75.8 76.  75.6]
# transform data :  [0.00116919993318858, 0.00233839986637716, 0.0025054284282612325, 0.0028394855520294015, 0.002171371304493063]
# recover data :  [75.0, 75.7, 75.8, 76.0, 75.6]

# %%
# 切分資料集
training_data = scalar_data[:training_len]
validation_data = scalar_data[training_len:]

# %%
# todo 決定Seq長度
seq_len = 5

def split_input_target(seq):
  input_txt = tf.expand_dims(seq[:-1],-1)
  target_txt = tf.expand_dims(seq[1:],-1)
  return input_txt,target_txt

# %%
def make_ds(data):
  data_slice = tf.data.Dataset.from_tensor_slices(data)
  data_sequence = data_slice.batch(seq_len+1,drop_remainder=True)

  dataset = data_sequence.map(split_input_target)
  return dataset

# %%
# 製作資料集
train_ds = make_ds(training_data)
val_ds = make_ds(validation_data)

for input_example,target_exaple in train_ds.take(1):
  print("Input :", scalar.recover(input_example.numpy()))
  print("Target:", scalar.recover(target_exaple.numpy()))
  print("-"*50)
  print("Input :", input_example.numpy())
  print("Target:", target_exaple.numpy())
# Out:
# Input : [array([75.]), array([75.7]), array([75.8]), array([76.]), array([75.6])]
# Target: [array([75.7]), array([75.8]), array([76.]), array([75.6]), array([75.6])]
# --------------------------------------------------
# Input : [[0.0011692 ]
#  [0.0023384 ]
#  [0.00250543]
#  [0.00283949]
#  [0.00217137]]
# Target: [[0.0023384 ]
#  [0.00250543]
#  [0.00283949]
#  [0.00217137]
#  [0.00217137]]

# %%
# Batch size
# todo 決定Batch大小
BATCH_SIZE = 8

BUFFER_SIZE = training_len

train_ds = train_ds.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_ds = val_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## 4. 建立模型
#
# 提示: Output是一個數值，所以Model output維度為1。
#
# * 輸入維度應為: (batch,seq_len,1)
#
# * 輸出維度應為: (batch,seq_len,1)
#
# **最後一層Dense不要加上任何activation function。**

# %%
# todo
input_shape = (5,1)
#不用加batch，因為前面batch在前面已經加入了
model = tf.keras.Sequential()
#model.add(tf.keras.layers.Embedding(8,5))
model.add(
  tf.keras.layers.LSTM(
    units=50,
    input_shape = (5,1),
    return_sequences=True,
))
model.add(Dropout(0.2))
model.add(
  tf.keras.layers.Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             10400
#
#  dropout (Dropout)           (None, 5, 50)             0
#
#  dense (Dense)               (None, 5, 1)              51
#
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. 制定訓練計畫並訓練
#
# 我們做數字相關預測，可以考慮用Mean_Squared_Error
#
# 公式:
# $$MSE = \frac{1}{n} \sum_{i=1}^N({\gamma-\hat{\gamma}})^2$$
#
#
# 提示:
# 不用管公式在幹嘛，compile帶入mean_squared_error。

# %%
# todo
epochs = 200

# todo
# model.compile
model.compile(optimizer='adam',loss='mean_squared_error')
# todo
# model.fit
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs,batch_size=8)
# Out:
# Epoch 1/200
# 44/44 [==============================] - 3s 19ms/step - loss: 1.0003e-04 - val_loss: 2.1868e-04
# Epoch 2/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0453e-04 - val_loss: 3.0363e-04
# Epoch 3/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0402e-04 - val_loss: 2.4913e-04
# Epoch 4/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0344e-04 - val_loss: 2.7520e-04
# Epoch 5/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9626e-05 - val_loss: 2.2837e-04
# Epoch 6/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5845e-05 - val_loss: 2.2723e-04
# Epoch 7/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0317e-04 - val_loss: 2.3352e-04
# Epoch 8/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0652e-04 - val_loss: 2.4854e-04
# Epoch 9/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7445e-05 - val_loss: 2.4325e-04
# Epoch 10/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0472e-04 - val_loss: 2.6325e-04
# Epoch 11/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0413e-04 - val_loss: 2.6563e-04
# Epoch 12/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.5262e-05 - val_loss: 2.9294e-04
# Epoch 13/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7402e-05 - val_loss: 4.0159e-04
# Epoch 14/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0525e-04 - val_loss: 2.3998e-04
# Epoch 15/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.8021e-05 - val_loss: 3.5992e-04
# Epoch 16/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8269e-05 - val_loss: 2.6456e-04
# Epoch 17/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.3772e-05 - val_loss: 5.0249e-04
# Epoch 18/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4136e-05 - val_loss: 3.1634e-04
# Epoch 19/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.9199e-05 - val_loss: 3.7220e-04
# Epoch 20/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.4743e-05 - val_loss: 2.3907e-04
# Epoch 21/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0165e-04 - val_loss: 2.3106e-04
# Epoch 22/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0224e-04 - val_loss: 2.6579e-04
# Epoch 23/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.2737e-05 - val_loss: 3.1783e-04
# Epoch 24/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8313e-05 - val_loss: 2.5123e-04
# Epoch 25/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9047e-05 - val_loss: 2.4361e-04
# Epoch 26/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0230e-04 - val_loss: 2.6149e-04
# Epoch 27/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0178e-04 - val_loss: 2.2060e-04
# Epoch 28/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9553e-05 - val_loss: 2.9836e-04
# Epoch 29/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0182e-04 - val_loss: 4.1462e-04
# Epoch 30/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.1312e-04 - val_loss: 2.4767e-04
# Epoch 31/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0554e-04 - val_loss: 2.2988e-04
# Epoch 32/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.1454e-05 - val_loss: 2.7166e-04
# Epoch 33/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0407e-04 - val_loss: 2.4657e-04
# Epoch 34/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9152e-05 - val_loss: 3.0161e-04
# Epoch 35/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0473e-04 - val_loss: 2.2126e-04
# Epoch 36/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0185e-04 - val_loss: 3.1261e-04
# Epoch 37/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.9108e-05 - val_loss: 3.1266e-04
# Epoch 38/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0966e-04 - val_loss: 2.5136e-04
# Epoch 39/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.3710e-05 - val_loss: 2.4122e-04
# Epoch 40/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4907e-05 - val_loss: 2.5131e-04
# Epoch 41/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0085e-04 - val_loss: 3.5996e-04
# Epoch 42/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0845e-04 - val_loss: 2.6199e-04
# Epoch 43/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0273e-04 - val_loss: 2.6871e-04
# Epoch 44/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5502e-05 - val_loss: 2.8515e-04
# Epoch 45/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0097e-04 - val_loss: 2.3944e-04
# Epoch 46/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.3470e-05 - val_loss: 3.0628e-04
# Epoch 47/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0134e-04 - val_loss: 2.9373e-04
# Epoch 48/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0347e-04 - val_loss: 2.6888e-04
# Epoch 49/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.1391e-04 - val_loss: 2.7991e-04
# Epoch 50/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8490e-05 - val_loss: 2.5135e-04
# Epoch 51/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0368e-04 - val_loss: 2.9585e-04
# Epoch 52/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0138e-04 - val_loss: 2.3972e-04
# Epoch 53/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.6188e-05 - val_loss: 2.4515e-04
# Epoch 54/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0557e-04 - val_loss: 2.7658e-04
# Epoch 55/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8375e-05 - val_loss: 3.1059e-04
# Epoch 56/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8835e-05 - val_loss: 2.6812e-04
# Epoch 57/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.6052e-05 - val_loss: 4.6840e-04
# Epoch 58/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0032e-04 - val_loss: 2.5259e-04
# Epoch 59/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0006e-04 - val_loss: 3.1348e-04
# Epoch 60/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.6941e-05 - val_loss: 2.9360e-04
# Epoch 61/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4490e-05 - val_loss: 3.6195e-04
# Epoch 62/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9005e-05 - val_loss: 2.6532e-04
# Epoch 63/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0884e-04 - val_loss: 2.4102e-04
# Epoch 64/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8518e-05 - val_loss: 2.8902e-04
# Epoch 65/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7622e-05 - val_loss: 2.5057e-04
# Epoch 66/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0598e-04 - val_loss: 4.3295e-04
# Epoch 67/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.5276e-05 - val_loss: 2.6157e-04
# Epoch 68/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.1007e-04 - val_loss: 2.5578e-04
# Epoch 69/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0879e-04 - val_loss: 4.3224e-04
# Epoch 70/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0536e-04 - val_loss: 3.7170e-04
# Epoch 71/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0096e-04 - val_loss: 3.2813e-04
# Epoch 72/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.2231e-05 - val_loss: 2.4252e-04
# Epoch 73/200
# 44/44 [==============================] - 0s 8ms/step - loss: 9.8438e-05 - val_loss: 3.0950e-04
# Epoch 74/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0291e-04 - val_loss: 4.6654e-04
# Epoch 75/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5013e-05 - val_loss: 3.5318e-04
# Epoch 76/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0663e-04 - val_loss: 3.0111e-04
# Epoch 77/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0250e-04 - val_loss: 2.5201e-04
# Epoch 78/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9304e-05 - val_loss: 3.3168e-04
# Epoch 79/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0359e-04 - val_loss: 2.4599e-04
# Epoch 80/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0275e-04 - val_loss: 2.4014e-04
# Epoch 81/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8800e-05 - val_loss: 2.6662e-04
# Epoch 82/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0270e-04 - val_loss: 6.9030e-04
# Epoch 83/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.5818e-05 - val_loss: 2.9218e-04
# Epoch 84/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4279e-05 - val_loss: 2.8055e-04
# Epoch 85/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0359e-04 - val_loss: 2.3427e-04
# Epoch 86/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8173e-05 - val_loss: 3.8133e-04
# Epoch 87/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0312e-04 - val_loss: 2.9081e-04
# Epoch 88/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.3174e-05 - val_loss: 2.5258e-04
# Epoch 89/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0151e-04 - val_loss: 3.8068e-04
# Epoch 90/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0787e-04 - val_loss: 2.1181e-04
# Epoch 91/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0929e-04 - val_loss: 2.8495e-04
# Epoch 92/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.5756e-05 - val_loss: 2.9051e-04
# Epoch 93/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0212e-04 - val_loss: 2.9903e-04
# Epoch 94/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5118e-05 - val_loss: 2.4105e-04
# Epoch 95/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9765e-05 - val_loss: 3.1662e-04
# Epoch 96/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5726e-05 - val_loss: 4.5811e-04
# Epoch 97/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8516e-05 - val_loss: 3.6117e-04
# Epoch 98/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8006e-05 - val_loss: 2.5359e-04
# Epoch 99/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8381e-05 - val_loss: 2.5008e-04
# Epoch 100/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0075e-04 - val_loss: 2.4938e-04
# Epoch 101/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0188e-04 - val_loss: 3.2594e-04
# Epoch 102/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.7817e-05 - val_loss: 2.5585e-04
# Epoch 103/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0099e-04 - val_loss: 2.6487e-04
# Epoch 104/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0046e-04 - val_loss: 3.1776e-04
# Epoch 105/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8390e-05 - val_loss: 2.2604e-04
# Epoch 106/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0057e-04 - val_loss: 2.6306e-04
# Epoch 107/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7886e-05 - val_loss: 2.5208e-04
# Epoch 108/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0130e-04 - val_loss: 2.2944e-04
# Epoch 109/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9295e-05 - val_loss: 3.2950e-04
# Epoch 110/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0703e-04 - val_loss: 2.5130e-04
# Epoch 111/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0123e-04 - val_loss: 2.5736e-04
# Epoch 112/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0014e-04 - val_loss: 2.8200e-04
# Epoch 113/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9051e-05 - val_loss: 2.5739e-04
# Epoch 114/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.1311e-04 - val_loss: 2.8027e-04
# Epoch 115/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.0432e-05 - val_loss: 2.5202e-04
# Epoch 116/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0161e-04 - val_loss: 3.2308e-04
# Epoch 117/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8564e-05 - val_loss: 2.4790e-04
# Epoch 118/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.0449e-05 - val_loss: 2.8959e-04
# Epoch 119/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8599e-05 - val_loss: 3.5234e-04
# Epoch 120/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5330e-05 - val_loss: 2.8414e-04
# Epoch 121/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7562e-05 - val_loss: 2.3614e-04
# Epoch 122/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.9683e-05 - val_loss: 3.0015e-04
# Epoch 123/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9768e-05 - val_loss: 2.6394e-04
# Epoch 124/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0337e-04 - val_loss: 2.4463e-04
# Epoch 125/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0215e-04 - val_loss: 3.5561e-04
# Epoch 126/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5780e-05 - val_loss: 3.1247e-04
# Epoch 127/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9784e-05 - val_loss: 2.5734e-04
# Epoch 128/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9761e-05 - val_loss: 6.1676e-04
# Epoch 129/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7298e-05 - val_loss: 2.6472e-04
# Epoch 130/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0604e-04 - val_loss: 3.0890e-04
# Epoch 131/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7223e-05 - val_loss: 3.5924e-04
# Epoch 132/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0498e-04 - val_loss: 2.8320e-04
# Epoch 133/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7376e-05 - val_loss: 3.4895e-04
# Epoch 134/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0435e-04 - val_loss: 2.6654e-04
# Epoch 135/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0119e-04 - val_loss: 2.3295e-04
# Epoch 136/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4881e-05 - val_loss: 2.6700e-04
# Epoch 137/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0594e-04 - val_loss: 2.8311e-04
# Epoch 138/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0185e-04 - val_loss: 3.8807e-04
# Epoch 139/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4258e-05 - val_loss: 2.4911e-04
# Epoch 140/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7848e-05 - val_loss: 2.4282e-04
# Epoch 141/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0239e-04 - val_loss: 2.7098e-04
# Epoch 142/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0152e-04 - val_loss: 2.6695e-04
# Epoch 143/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8208e-05 - val_loss: 3.1510e-04
# Epoch 144/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0153e-04 - val_loss: 2.6977e-04
# Epoch 145/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.6779e-05 - val_loss: 4.7295e-04
# Epoch 146/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.2603e-05 - val_loss: 3.2932e-04
# Epoch 147/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.6905e-05 - val_loss: 3.3296e-04
# Epoch 148/200
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0041e-04 - val_loss: 2.6805e-04
# Epoch 149/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0650e-04 - val_loss: 3.9061e-04
# Epoch 150/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0061e-04 - val_loss: 2.2010e-04
# Epoch 151/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.0344e-05 - val_loss: 3.5628e-04
# Epoch 152/200
# 44/44 [==============================] - 0s 6ms/step - loss: 9.7840e-05 - val_loss: 3.0657e-04
# Epoch 153/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0093e-04 - val_loss: 2.5216e-04
# Epoch 154/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.3670e-05 - val_loss: 2.4320e-04
# Epoch 155/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8228e-05 - val_loss: 2.3012e-04
# Epoch 156/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0377e-04 - val_loss: 2.4514e-04
# Epoch 157/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7755e-05 - val_loss: 5.1303e-04
# Epoch 158/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0104e-04 - val_loss: 3.7455e-04
# Epoch 159/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7086e-05 - val_loss: 3.0507e-04
# Epoch 160/200
# 44/44 [==============================] - 0s 7ms/step - loss: 8.9145e-05 - val_loss: 3.3680e-04
# Epoch 161/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4915e-05 - val_loss: 6.1296e-04
# Epoch 162/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7601e-05 - val_loss: 2.2245e-04
# Epoch 163/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0117e-04 - val_loss: 2.5217e-04
# Epoch 164/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.2025e-05 - val_loss: 2.6695e-04
# Epoch 165/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0430e-04 - val_loss: 2.7293e-04
# Epoch 166/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4841e-05 - val_loss: 2.4325e-04
# Epoch 167/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9002e-05 - val_loss: 2.3785e-04
# Epoch 168/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4337e-05 - val_loss: 2.2437e-04
# Epoch 169/200
# 44/44 [==============================] - 0s 7ms/step - loss: 8.4445e-05 - val_loss: 2.4861e-04
# Epoch 170/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9450e-05 - val_loss: 2.4489e-04
# Epoch 171/200
# 44/44 [==============================] - 0s 7ms/step - loss: 8.8719e-05 - val_loss: 2.7600e-04
# Epoch 172/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.1954e-05 - val_loss: 2.1886e-04
# Epoch 173/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.1803e-05 - val_loss: 2.5645e-04
# Epoch 174/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0501e-04 - val_loss: 2.8727e-04
# Epoch 175/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0096e-04 - val_loss: 2.5149e-04
# Epoch 176/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9947e-05 - val_loss: 2.8589e-04
# Epoch 177/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5989e-05 - val_loss: 2.6339e-04
# Epoch 178/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0306e-04 - val_loss: 2.9962e-04
# Epoch 179/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0017e-04 - val_loss: 2.6088e-04
# Epoch 180/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7738e-05 - val_loss: 2.4560e-04
# Epoch 181/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0476e-04 - val_loss: 2.3426e-04
# Epoch 182/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.5476e-05 - val_loss: 2.6593e-04
# Epoch 183/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4736e-05 - val_loss: 2.9545e-04
# Epoch 184/200
# 44/44 [==============================] - 0s 8ms/step - loss: 9.7179e-05 - val_loss: 2.3266e-04
# Epoch 185/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7692e-05 - val_loss: 2.7018e-04
# Epoch 186/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.9329e-05 - val_loss: 2.7769e-04
# Epoch 187/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8689e-05 - val_loss: 3.0006e-04
# Epoch 188/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0765e-04 - val_loss: 4.8428e-04
# Epoch 189/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0858e-04 - val_loss: 2.7411e-04
# Epoch 190/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.7347e-05 - val_loss: 3.8294e-04
# Epoch 191/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4089e-05 - val_loss: 3.7549e-04
# Epoch 192/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.1233e-04 - val_loss: 2.7181e-04
# Epoch 193/200
# 44/44 [==============================] - 0s 8ms/step - loss: 9.8296e-05 - val_loss: 2.4026e-04
# Epoch 194/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.8839e-05 - val_loss: 3.4897e-04
# Epoch 195/200
# 44/44 [==============================] - 0s 8ms/step - loss: 1.0516e-04 - val_loss: 2.2534e-04
# Epoch 196/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0106e-04 - val_loss: 3.6827e-04
# Epoch 197/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.6926e-05 - val_loss: 2.2158e-04
# Epoch 198/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0238e-04 - val_loss: 2.5110e-04
# Epoch 199/200
# 44/44 [==============================] - 0s 7ms/step - loss: 9.4069e-05 - val_loss: 2.7607e-04
# Epoch 200/200
# 44/44 [==============================] - 0s 7ms/step - loss: 1.0111e-04 - val_loss: 2.3517e-04

# %% [markdown]
# ## 6. 評估模型

# %%
l1, = plt.plot(history.history['loss'])
l2, = plt.plot(history.history['val_loss'])
plt.legend(handles=[l1,l2],labels=['loss','val_loss'],loc='best')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.show()

# %%
test_company = test_df[test_df["company"] == company_id]
test_company.head()
# Out:
#     company      date  price
# 38     2330  2021/2/1  611.0
# 37     2330  2021/2/2  632.0
# 36     2330  2021/2/3  630.0
# 35     2330  2021/2/4  627.0
# 34     2330  2021/2/5  632.0

# %% [markdown]
# ## 7. 做預測 (20分)

# %%
# 預測 Test data
# 現在我們取出了選定公司最後seq_len天
# 我們模型透過讀取seq_len天後預測出seq_len+1天的價格

# 將日期保存在datas中 (list)
# 將真實價格保存在real_prices中 (list)
# 將預測價格保存在pred_prices中 (list) *注: 請填入經過正規化後的價格

# input是一個經過**正規化**的真實價格list，請試著遍歷test_company來填滿上述三個list
# 可以參考TextGeneration的generateWords function，概念一樣，但是這次input請全部都填入"真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"

init_price = company.iloc[-seq_len:,:]["price"].values
dates = []
real_prices = []
pred_prices = []
input = scalar.transform(init_price)#input為company price經過minmax號介於0跟1的值


for index,row in test_company.iterrows():
  # 我已經幫你把real_price和date放入list
  real_price = row["price"]
  real_prices.append(real_price)
  date = row["date"]
  dates.append(date)

  
  
  # 參考步驟 (在for迴圈中) :
  # 1. 把input轉**維度**成一個新變數next_input丟入model
  next_input = tf.expand_dims(input,axis=1)
  pred = model(next_input)
  # 2. 獲得的pred取出seq中最後一個時間點的output數值 (提示: [0,-1,0])
  pred = pred[0,-1,0]
  # 3. 把pred丟入pred_prices中
  pred_prices.append(pred.numpy())
  # 4. 把real_price經過transform_one轉換成小數點並加在input後面
  transform_one_real_price = scalar.transform_one(real_price)
  input.append(transform_one_real_price)
  # 5. 保持input長度為seq_len長 (也就是把最前面的數字踢掉)
  input.pop(0)

# %%
print(f"dates : {dates[:10]}")
print(f"real_prices : {real_prices[:10]}")
print(f"pred_prices : {pred_prices[:10]}")
# Out:
# dates : ['2021/2/1', '2021/2/2', '2021/2/3', '2021/2/4', '2021/2/5', '2021/2/17', '2021/2/18', '2021/2/19', '2021/2/22', '2021/2/23']
# real_prices : [611.0, 632.0, 630.0, 627.0, 632.0, 663.0, 660.0, 652.0, 650.0, 641.0]
# pred_prices : [0.9269497, 0.90092564, 0.8976681, 0.874839, 0.8585042, 0.89115036, 0.92532516, 0.92207515, 0.9171983, 0.92532516]

# %% [markdown]
# * 預期結果:
#
# ![](https://i.imgur.com/iXdMWD6.png)

# %%
plt.figure(figsize=(16, 8))
l1, = plt.plot(dates,real_prices)
l2, = plt.plot(dates,scalar.recover(pred_prices))
plt.xticks(list(include_last_iter(0,len(dates),3)),rotation=30)
plt.legend(handles=[l1,l2],labels=['Real','Pred'],loc='best')
plt.title(companys[str(company_id)])
plt.xlabel("Date")
plt.ylabel("price")
plt.show()

# %% [markdown]
# * 預期成果
#
# 照理來說不會100%猜中，猜中幾乎100%可能是不小心偷看答案了。
#
# 不過要是你的模型正確的話，應該會看到如下pred price在true price附近而不是躺在地上。
#
# ![](https://i.imgur.com/tFoKEyK.png)
